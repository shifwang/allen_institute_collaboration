# %% [markdown]
# # Stability analysis of NMF patterns

# %%
import numpy as np
import sklearn
from nmf_with_missing_values import nmf_with_missing_values
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import euclidean_distances
import scipy as sp
from utils import correlation_map_with_CCF
# %matplotlib inline

# %% [markdown]
# ## load data

# %%
tmp = np.load('../data/mouse_brain_ISH_float32.npz')
data = tmp['data']
sections = tmp['sections'].item()
original_shape = data.shape
d = data.shape[1] * data.shape[2] * data.shape[3]
data = np.reshape(data, (data.shape[0], d))

# %% [markdown]
# ## stability analysis for NMF patterns

# %%
for i in range(20):
    #f = np.load('../code/reza/nmf_result_ncomp_18.npz')
    f = np.load('../data/stability_result_comp_18_{}.npz'.format(i))
    #print(np.sum(f['data']))
    PPs = f['A']
    original_shape = f['original_shape']
    X_guess = f['X_guess']
    coefs = f['D']
    corr_mat = correlation_map_with_CCF(PPs, original_shape, order_type=2,area_order=[1,9,3,11,4,8,0,2,10,5,6,7], put_last_k=4, save_fig=True, save_index=i)

# %% [markdown]
# ### create gif

# %%
import imageio
images = []
for i in range(20):
    images.append(imageio.imread('plot_{}.png'.format(i)))
imageio.mimsave('nmf.gif', images, duration=0.5)

# %% [markdown]
# ## stability analysis for PCA patterns

# %%
for i in range(20):
    #f = np.load('../code/reza/nmf_result_ncomp_18.npz')
    f = np.load('../data/stability_pca_result_comp_18_{}.npz'.format(i))
    PPs = f['PPs']
    original_shape = f['original_shape']
    X_guess = f['X_guess']
    coefs = f['coefs']
    corr_mat = correlation_map_with_CCF(PPs, original_shape, order_type=2,area_order=[1,9,3,11,4,8,0,2,10,5,6,7], put_last_k=4, save_fig=True, save_index=i)

# %% [markdown]
# ### create gif

# %%
import imageio
images = []
for i in range(20):
    images.append(imageio.imread('plot_{}.png'.format(i)))
imageio.mimsave('pca.gif', images, duration=0.5)
